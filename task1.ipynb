# %% [markdown]
# <a href="https://colab.research.google.com/github/maitridkhode-svg/Maitri-Khode./blob/main/task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Sum of two numbers
num1=int(input("Enter first number:"))
num2=int(input("Enter second number:"))
sum=num1+num2
print("Sum of two numbers is:",sum)
# Out:
# Enter first number:7
# Enter second number:9
# Sum of two numbers is: 16

# %%
#Check if gven number is odd or even
num=int(input("Enter a number:"))
if num%2==0:
    print("Given number is even")
else:
    print("Given number is odd")
# Out:
# Enter a number:-7
# Given number is odd

# %%
#Find factorial of given number
num=int(input("Enter a number:"))
if num<0:
  print("Invalid input")
elif num==0:
  print("Factorial of 0 : 1")
else:
  fact=1
  for num1 in range(1,num+1):
    fact*=num1

print("Factorial of ",num,":",fact)
# Out:
# Enter a number:3
# Factorial of  3 : 6

# %%
#Fibonacci Sequence
num=int(input("Enter a number:"))

a, b = 1, 1
count = 0

if num <= 0:
    print("Please enter a positive integer")
elif num == 1:
    print("Fibonacci sequence up to", num, ":")
    print(a)
else:
    print("Fibonacci sequence:")
    while count < num:
        print(a, end=" ")
        nth = a + b
        a = b
        b = nth
        count += 1
# Out:
# Enter a number:5
# Fibonacci sequence:
# 1 1 2 3 5

# %%
#Reverse a string
sentence=input("Enter a string:")
print("Reverse of given string is:",sentence[::-1])
# Out:
# Enter a string:hello myself abc
# Reverse of given string is: cba flesym olleh

# %%
#Palindrome check
num=int(input("Enter a number:"))
num1=str(num)

if num1 == num1[::-1]:
    print(f"{num} is a palindrome")
else:
    print(f"{num} is not a palindrome")
# Out:
# Enter a number:808
# 808 is a palindrome

# %%
#Check if a given year is leap year or not
year=int(input("Enter a year:"))
if (year%4==0 and year%100!=0) or (year%400==0):
    print(f"{year} is a leap year")
else:
    print(f"{year} is not a leap year")
# Out:
# Enter a year:2026
# 2026 is not a leap year

# %%
#Armstrong number
num=int(input("Enter a number:"))
num1=str(num)
pow=len(num1)
sum=0
for i in num1:
    sum+=int(i)**pow
if sum==num:
    print(f"{num} is an armstrong number")
else:
    print(f"{num} is not an armstrong number")
# Out:
# Enter a number:153
# 153 is an armstrong number
